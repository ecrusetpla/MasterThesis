# %% [markdown]
# # Compile CBS Proximity datasets into one wide dataset
#
# This notebook:
# 1. Reads all CSV files in the current folder that start with **`Proximity - Regional designation`**
# 2. Cleans/standardizes identifiers
# 3. Merges all indicator columns into one *wide* dataset
# 4. Saves the result as a CSV (and optionally Parquet)
# 5. Produces a few example exploratory plots

# %%
import os
import re
import glob
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = Path("C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/proximity/")  
paths = sorted(DATA_DIR.glob("*.csv"))
paths
# Out:
# [WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/proximity/Proximity - Regional designation - Education.csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/proximity/Proximity - Regional designation - Green areas.csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/proximity/Proximity - Regional designation - Health and Wellbeing.csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/proximity/Proximity - Regional designation - Retail.csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/proximity/Proximity - Regional designation - Transport.csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/proximity/Proximity - Regional designation.csv')]

# %%
def read_cbs_csv(path: str) -> pd.DataFrame:
    """Read CBS-style CSVs (semicolon-separated, decimal comma) robustly."""
    return pd.read_csv(
        path,
        sep=";",
        engine="python",
        encoding="utf-8-sig",
        decimal=",",
        on_bad_lines="skip",
    )

def find_year_column(df: pd.DataFrame) -> str | None:
    candidates = []
    for c in df.columns:
        if re.search(r"\b(perioden|periode|jaar|year)\b", c, flags=re.I):
            candidates.append(c)
    return candidates[0] if candidates else None

ID_COLS_BASE = [
    "Wijken en buurten",
    "Regioaanduiding/Gemeentenaam (naam)",
    "Regioaanduiding/Soort regio (omschrijving)",
    "Regioaanduiding/Codering (code)",
    "Regioaanduiding/Indelingswijziging wijken en buurten (code)",
]

def standardize(df: pd.DataFrame) -> pd.DataFrame:
    """Standardize identifiers and add a `year` column if possible."""
    df = df.copy()
    year_col = find_year_column(df)
    if year_col is not None:
        # Try to extract a 4-digit year if the column is like '2023' or '2023JJ00'
        df["year"] = (
            df[year_col]
            .astype(str)
            .str.extract(r"(19\d{2}|20\d{2})", expand=False)
        )
        df.drop(columns=[year_col], inplace=True)
    else:
        df["year"] = np.nan  # constant if no year column is present

    # Clean region code and names a bit
    code_col = "Regioaanduiding/Codering (code)"
    if code_col in df.columns:
        df[code_col] = df[code_col].astype(str).str.strip()

    for c in ["Wijken en buurten", "Regioaanduiding/Gemeentenaam (naam)"]:
        if c in df.columns:
            df[c] = df[c].astype(str).str.strip()

    return df

def indicator_columns(df: pd.DataFrame) -> list[str]:
    id_cols = set(ID_COLS_BASE + ["year"])
    return [c for c in df.columns if c not in id_cols]

# %%
# Read and merge all files
frames = []
for path in paths:
    df = standardize(read_cbs_csv(path))
    inds = indicator_columns(df)

    # Prefix indicator column names by category inferred from filename
    fname = os.path.basename(path)
    # e.g. "Proximity - Regional designation - Retail.csv" -> "Retail"
    m = re.search(r"Proximity - Regional designation(?: - (.*))?\.csv$", fname)
    category = (m.group(1) if m and m.group(1) else "Base").strip()

    rename_map = {c: f"{category} | {c}" for c in inds}
    df = df[ID_COLS_BASE + ["year"] + inds].rename(columns=rename_map)

    frames.append(df)

# Merge on neighbourhood code + year (and keep descriptive columns)
from functools import reduce

KEY_COLS = ["Regioaanduiding/Codering (code)", "year"]
DESC_COLS = [c for c in ID_COLS_BASE if c != KEY_COLS[0]]

def merge_two(left: pd.DataFrame, right: pd.DataFrame) -> pd.DataFrame:
    # Ensure we don't duplicate description columns during merge
    drop_desc = [c for c in DESC_COLS if c in right.columns]
    right2 = right.drop(columns=drop_desc, errors="ignore")
    return left.merge(right2, on=KEY_COLS, how="outer")

wide = reduce(merge_two, frames)

# Bring description columns to the front (prefer non-null from any frame)
# We'll reconstruct a single set of description columns by taking first non-null across frames.
desc_parts = []
for df in frames:
    cols = [KEY_COLS[0]] + DESC_COLS + ["year"]
    cols = [c for c in cols if c in df.columns]
    desc_parts.append(df[cols])

desc = pd.concat(desc_parts, ignore_index=True)
desc = desc.groupby(KEY_COLS, dropna=False).agg(lambda s: s.dropna().iloc[0] if s.dropna().size else np.nan).reset_index()

# Attach descriptions back
wide = wide.drop(columns=[c for c in DESC_COLS if c in wide.columns], errors="ignore")
wide = desc.merge(wide, on=KEY_COLS, how="right")

wide.shape, wide.columns[:10]
# Out:
# ((18310, 69),
#  Index(['Regioaanduiding/Codering (code)', 'year', 'Wijken en buurten',
#         'Regioaanduiding/Gemeentenaam (naam)',
#         'Regioaanduiding/Soort regio (omschrijving)',
#         'Regioaanduiding/Indelingswijziging wijken en buurten (code)',
#         'Education | Onderwijs/Basisonderwijs/Afstand tot school (km)',
#         'Education | Onderwijs/Basisonderwijs/Aantal scholen/Binnen 1 km (aantal)',
#         'Education | Onderwijs/Basisonderwijs/Aantal scholen/Binnen 3 km (aantal)',
#         'Education | Onderwijs/Basisonderwijs/Aantal scholen/Binnen 5 km (aantal)'],
#        dtype='object'))

# %%
# Quick sanity checks
wide.head()
# Out:
#   Regioaanduiding/Codering (code)  year Wijken en buurten  \
# 0                      BU00140000   NaN  Binnenstad-Noord
# 1                      BU00140001   NaN   Binnenstad-Zuid
# 2                      BU00140002   NaN   Binnenstad-Oost
# 3                      BU00140003   NaN   Binnenstad-West
# 4                      BU00140004   NaN  Noorderplantsoen
#
#   Regioaanduiding/Gemeentenaam (naam)  \
# 0                           Groningen
# 1                           Groningen
# 2                           Groningen
# 3                           Groningen
# 4                           Groningen
#
#   Regioaanduiding/Soort regio (omschrijving)  \
# 0                                 Buurt
# 1                                 Buurt
# 2                                 Buurt
# 3                                 Buurt
# 4                                 Buurt
#
#   Regioaanduiding/Indelingswijziging wijken en buurten (code)  \
# 0                                                  1
# ...

# %%
# How many indicators?
indicator_cols = [c for c in wide.columns if c not in (DESC_COLS + KEY_COLS)]
len(indicator_cols)
# Out:
# 63

# %%
# Missingness overview (top 20 most-missing indicators)
missing = wide[indicator_cols].isna().mean().sort_values(ascending=False)
missing.head(20)
# Out:
# Green areas | Groenvoorzieningen/Openbaar groen/Afstand tot open natuurlijk terrein/Afstand tot open nat natuurlijk terrein (km)    1.000000
# Green areas | Groenvoorzieningen/Openbaar groen/Afstand tot open natuurlijk terrein/Afstand tot open nat. terrein totaal (km)       1.000000
# Green areas | Groenvoorzieningen/Afstand tot recreatief binnenwater (km)                                                            1.000000
# Green areas | Groenvoorzieningen/Semi-openbaar groen/Afstand tot verblijfsrecreatief terrein (km)                                   1.000000
# Green areas | Groenvoorzieningen/Semi-openbaar groen/Afstand tot volkstuin (km)                                                     1.000000
# Green areas | Groenvoorzieningen/Semi-openbaar groen/Afstand tot sportterrein (km)                                                  1.000000
# ...

# %%
amenity_translations = {
    # Region Info
    'Regioaanduiding/Codering (code)': 'Region_Code',
    'Wijken en buurten': 'Neighborhood_Name',
    'Regioaanduiding/Gemeentenaam (naam)': 'Municipality_Name',
    'Regioaanduiding/Soort regio (omschrijving)': 'Region_Type',
    'Regioaanduiding/Indelingswijziging wijken en buurten (code)': 'Boundary_Change_Code',

    # Education - Primary
    'Education | Onderwijs/Basisonderwijs/Afstand tot school (km)': 'Dist_Primary_School',
    'Education | Onderwijs/Basisonderwijs/Aantal scholen/Binnen 1 km (aantal)': 'Count_Primary_1km',
    'Education | Onderwijs/Basisonderwijs/Aantal scholen/Binnen 3 km (aantal)': 'Count_Primary_3km',
    'Education | Onderwijs/Basisonderwijs/Aantal scholen/Binnen 5 km (aantal)': 'Count_Primary_5km',

    # Education - Secondary Total
    'Education | Onderwijs/Voortgezet onderwijs/Voortgezet onderwijs totaal/Afstand tot school (km)': 'Dist_Secondary_Total',
    'Education | Onderwijs/Voortgezet onderwijs/Voortgezet onderwijs totaal/Aantal scholen/Binnen 3 km (aantal)': 'Count_Secondary_3km',
    'Education | Onderwijs/Voortgezet onderwijs/Voortgezet onderwijs totaal/Aantal scholen/Binnen 5 km (aantal)': 'Count_Secondary_5km',
    'Education | Onderwijs/Voortgezet onderwijs/Voortgezet onderwijs totaal/Aantal scholen/Binnen 10 km (aantal)': 'Count_Secondary_10km',

    # Education - VMBO
    'Education | Onderwijs/Voortgezet onderwijs/Vmbo/Afstand tot school (km)': 'Dist_Secondary_VMBO',
    'Education | Onderwijs/Voortgezet onderwijs/Vmbo/Aantal scholen/Binnen 3\xa0 km (aantal)': 'Count_Secondary_VMBO_3km',
    'Education | Onderwijs/Voortgezet onderwijs/Vmbo/Aantal scholen/Binnen 5\xa0 km (aantal)': 'Count_Secondary_VMBO_5km',
    'Education | Onderwijs/Voortgezet onderwijs/Vmbo/Aantal scholen/Binnen 10\xa0 km (aantal)': 'Count_Secondary_VMBO_10km',

    # Education - HAVO/VWO
    'Education | Onderwijs/Voortgezet onderwijs/Havo/vwo/Afstand tot school (km)': 'Dist_Secondary_HAVO_VWO',
    'Education | Onderwijs/Voortgezet onderwijs/Havo/vwo/Aantal scholen/Binnen 3 km (aantal)': 'Count_Secondary_HAVO_VWO_3km',
    'Education | Onderwijs/Voortgezet onderwijs/Havo/vwo/Aantal scholen/Binnen 5 km (aantal)': 'Count_Secondary_HAVO_VWO_5km',
    'Education | Onderwijs/Voortgezet onderwijs/Havo/vwo/Aantal scholen/Binnen 10 km (aantal)': 'Count_Secondary_HAVO_VWO_10km',

    # Green Areas
    'Green areas | Groenvoorzieningen/Openbaar groen/Afstand tot openbaar groen totaal (km)': 'Dist_Public_Green_Total',
    'Green areas | Groenvoorzieningen/Openbaar groen/Afstand tot park of plantsoen (km)': 'Dist_Park',
    'Green areas | Groenvoorzieningen/Openbaar groen/Afstand tot dagrecreatief terrein (km)': 'Dist_Day_Recreation',
    'Green areas | Groenvoorzieningen/Openbaar groen/Afstand tot bos (km)': 'Dist_Forest',
    'Green areas | Groenvoorzieningen/Openbaar groen/Afstand tot open natuurlijk terrein/Afstand tot open nat. terrein totaal (km)': 'Dist_Nature_Area_Total',
    'Green areas | Groenvoorzieningen/Openbaar groen/Afstand tot open natuurlijk terrein/Afstand tot open droog nat. terrein (km)': 'Dist_Nature_Area_Dry',
    'Green areas | Groenvoorzieningen/Openbaar groen/Afstand tot open natuurlijk terrein/Afstand tot open nat natuurlijk terrein (km)': 'Dist_Nature_Area_Wet',
    'Green areas | Groenvoorzieningen/Semi-openbaar groen/Afstand tot semi-openbaar groen totaal (km)': 'Dist_SemiPublic_Green',
    'Green areas | Groenvoorzieningen/Semi-openbaar groen/Afstand tot sportterrein (km)': 'Dist_Sports_Field',
    'Green areas | Groenvoorzieningen/Semi-openbaar groen/Afstand tot volkstuin (km)': 'Dist_Allotment_Garden',
    'Green areas | Groenvoorzieningen/Semi-openbaar groen/Afstand tot verblijfsrecreatief terrein (km)': 'Dist_Holiday_Recreation',
    'Green areas | Groenvoorzieningen/Semi-openbaar groen/Afstand tot begraafplaats (km)': 'Dist_Cemetery',
    'Green areas | Groenvoorzieningen/Afstand tot recreatief binnenwater (km)': 'Dist_Recreation_Water',

    # Health and Wellbeing
    'Health and Wellbeing | Gezondheid en welzijn/Huisartsenpraktijk/Afstand tot huisartsenpraktijk (km)': 'Dist_GP_Surgery',
    'Health and Wellbeing | Gezondheid en welzijn/Huisartsenpraktijk/Aantal huisartsenpraktijken/Binnen 1 km (aantal)': 'Count_GP_1km',
    'Health and Wellbeing | Gezondheid en welzijn/Huisartsenpraktijk/Aantal huisartsenpraktijken/Binnen 3 km (aantal)': 'Count_GP_3km',
    'Health and Wellbeing | Gezondheid en welzijn/Huisartsenpraktijk/Aantal huisartsenpraktijken/Binnen 5 km (aantal)': 'Count_GP_5km',
    'Health and Wellbeing | Gezondheid en welzijn/Huisartsenpraktijk/Afstand tot huisartsenpost (km)': 'Dist_GP_Out_Of_Hours',
    'Health and Wellbeing | Gezondheid en welzijn/Afstand tot apotheek (km)': 'Dist_Pharmacy',
    'Health and Wellbeing | Gezondheid en welzijn/Ziekenhuis (incl. buitenpolikliniek)/Afstand tot ziekenhuis (km)': 'Dist_Hospital_Incl_Outpatient',
    'Health and Wellbeing | Gezondheid en welzijn/Ziekenhuis (incl. buitenpolikliniek)/Aantal ziekenhuizen/Binnen 5 km (aantal)': 'Count_Hospital_Incl_5km',
    'Health and Wellbeing | Gezondheid en welzijn/Ziekenhuis (incl. buitenpolikliniek)/Aantal ziekenhuizen/Binnen 10 km (aantal)': 'Count_Hospital_Incl_10km',
    'Health and Wellbeing | Gezondheid en welzijn/Ziekenhuis (incl. buitenpolikliniek)/Aantal ziekenhuizen/Binnen 20 km (aantal)': 'Count_Hospital_Incl_20km',
    'Health and Wellbeing | Gezondheid en welzijn/Ziekenhuis (excl. buitenpolikliniek)/Afstand tot ziekenhuis (km)': 'Dist_Hospital_Excl_Outpatient',
    'Health and Wellbeing | Gezondheid en welzijn/Ziekenhuis (excl. buitenpolikliniek)/Aantal ziekenhuizen/Binnen 5 km (aantal)': 'Count_Hospital_Excl_5km',
    'Health and Wellbeing | Gezondheid en welzijn/Ziekenhuis (excl. buitenpolikliniek)/Aantal ziekenhuizen/Binnen 10 km (aantal)': 'Count_Hospital_Excl_10km',
    'Health and Wellbeing | Gezondheid en welzijn/Ziekenhuis (excl. buitenpolikliniek)/Aantal ziekenhuizen/Binnen 20 km (aantal)': 'Count_Hospital_Excl_20km',
    'Health and Wellbeing | Gezondheid en welzijn/Afstand tot consultatiebureau (km)': 'Dist_Clinic_Infant_Child',
    'Health and Wellbeing | Gezondheid en welzijn/Fysiotherapeut/Afstand tot fysiotherapeut (km)': 'Dist_Physiotherapist',
    'Health and Wellbeing | Gezondheid en welzijn/Fysiotherapeut/Aantal fysiotherapeuten/Binnen 1 km (aantal)': 'Count_Physio_1km',
    'Health and Wellbeing | Gezondheid en welzijn/Fysiotherapeut/Aantal fysiotherapeuten/Binnen 3 km (aantal)': 'Count_Physio_3km',
    'Health and Wellbeing | Gezondheid en welzijn/Fysiotherapeut/Aantal fysiotherapeuten/Binnen 5 km (aantal)': 'Count_Physio_5km',

    # Retail
    'Retail | Detailhandel/Winkels dagelijkse boodschappen/Afstand tot grote supermarkt (km)': 'Dist_Supermarket',
    'Retail | Detailhandel/Winkels dagelijkse boodschappen/Aantal grote supermarkten/Binnen 1 km (aantal)': 'Count_Supermarket_1km',
    'Retail | Detailhandel/Winkels dagelijkse boodschappen/Aantal grote supermarkten/Binnen 3 km (aantal)': 'Count_Supermarket_3km',
    'Retail | Detailhandel/Winkels dagelijkse boodschappen/Aantal grote supermarkten/Binnen 5 km (aantal)': 'Count_Supermarket_5km',
    'Retail | Detailhandel/Winkels dagelijkse boodschappen/Afstand tot ov. dagel. levensmiddelen (km)': 'Dist_Other_Grocery',
    'Retail | Detailhandel/Winkels dagelijkse boodschappen/Aantal overige dagelijkse levensmiddelen/Binnen 1 km (aantal)': 'Count_Other_Grocery_1km',
    'Retail | Detailhandel/Winkels dagelijkse boodschappen/Aantal overige dagelijkse levensmiddelen/Binnen 3 km (aantal)': 'Count_Other_Grocery_3km',
    'Retail | Detailhandel/Winkels dagelijkse boodschappen/Aantal overige dagelijkse levensmiddelen/Binnen 5 km (aantal)': 'Count_Other_Grocery_5km',
    'Retail | Detailhandel/Warenhuis/Afstand tot warenhuis (km)': 'Dist_Department_Store',
    'Retail | Detailhandel/Warenhuis/Aantal warenhuizen/Binnen 5 km (aantal)': 'Count_DeptStore_5km',
    'Retail | Detailhandel/Warenhuis/Aantal warenhuizen/Binnen 10 km (aantal)': 'Count_DeptStore_10km',
    'Retail | Detailhandel/Warenhuis/Aantal warenhuizen/Binnen 20 km (aantal)': 'Count_DeptStore_20km',

    # Transport
    'Transport | Verkeer en vervoer/Afstand tot oprit hoofdverkeersweg (km)': 'Dist_Highway_Entrance',
    'Transport | Verkeer en vervoer/Treinstations/Afstand tot treinstations totaal (km)': 'Dist_Train_Station_Total',
    'Transport | Verkeer en vervoer/Treinstations/Afstand tot belangrijk overstapstation (km)': 'Dist_Major_Transfer_Station'
}

# Apply to your dataframe
wide.rename(columns=amenity_translations, inplace=True)

# %% [markdown]
# ## Save the compiled dataset

# %%
OUT_CSV = "C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/processed/proximity_compiled_wide.csv"
wide.to_csv(OUT_CSV, index=False)
OUT_CSV
# Out:
# 'C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/processed/proximity_compiled_wide.csv'

# %% [markdown]
# ## Exploratory plots

# %%
x_col = 'Dist_Secondary_Total'
plt.figure()
wide[x_col].dropna().hist(bins=50)
plt.title(f"Distribution of: {x_col}")
plt.xlabel(x_col)
plt.ylabel("Count")
plt.show()

# %%
region_type_col = "Region_Type"
if x_col is not None and region_type_col in wide.columns:
    # Use up to the 6 most frequent region types to keep the chart readable
    top_types = wide[region_type_col].value_counts().head(6).index
    df_box = wide.loc[wide[region_type_col].isin(top_types), [region_type_col, x_col]].dropna()
    plt.figure()
    df_box.boxplot(column=x_col, by=region_type_col, rot=45)
    plt.title(f"{x_col} by {region_type_col}")
    plt.suptitle("")  # remove automatic suptitle
    plt.xlabel(region_type_col)
    plt.ylabel(x_col)
    plt.tight_layout()
    plt.show()
