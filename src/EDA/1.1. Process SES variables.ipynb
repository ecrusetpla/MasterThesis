# %% [markdown]
# # Compile Socioeconomic status datasets (neighbourhood × year)
#
# This notebook reads all provided CSV files, harmonizes keys (`neighbourhood_code`, `year`) and produces a single **wide** dataset with all indicators as columns.
#
# Outputs:
# - `compiled_neighbourhood_year_wide.parquet`
# - `compiled_neighbourhood_year_wide.csv`

# %%
import re
from pathlib import Path
import pandas as pd
import numpy as np

# %%
DATA_DIR = Path("C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/socioeconomic/")  
csv_files = sorted(DATA_DIR.glob("*.csv"))
csv_files
# Out:
# [WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/socioeconomic/Socioeconomic status by neighbourhood - All (2020).csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/socioeconomic/Socioeconomic status by neighbourhood - All (2021).csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/socioeconomic/Socioeconomic status by neighbourhood - All (2022).csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/socioeconomic/Socioeconomic status by neighbourhood - All (2023).csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/socioeconomic/Socioeconomic status by neighbourhood - Assets (2014-2019).csv'),
#  WindowsPath('C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/socioeconomic/Socioeconomic status by neighbourhood - Employment (2014-19).csv'),
# ...

# %% [markdown]
# ## Helper functions

# %%
def read_cbs_csv(path: Path) -> pd.DataFrame:

    return pd.read_csv(
        path,
        sep=";",
        decimal=",",
        engine="python",
        encoding="utf-8-sig",
        on_bad_lines="skip",
    )

def normalize_key_cols(df: pd.DataFrame) -> pd.DataFrame:
    """Standardize neighbourhood code/name + year columns."""
    df = df.copy()

    col_year = next((c for c in df.columns if c.strip().lower() == "perioden"), None)
    col_name = next((c for c in df.columns if c.strip().lower() == "wijken en buurten"), None)
    col_code = next((c for c in df.columns if "regiocode" in c.strip().lower()), None)

    if col_year is None or col_name is None or col_code is None:
        raise ValueError(f"Could not find key columns. Columns were: {list(df.columns)}")

    df = df.rename(columns={col_year: "year", col_name: "neighbourhood", col_code: "neighbourhood_code"})

    df["neighbourhood_code"] = df["neighbourhood_code"].astype(str).str.strip()
    df["neighbourhood"] = df["neighbourhood"].astype(str).str.strip()

    df["year"] = (
        df["year"]
        .astype(str)
        .str.extract(r"(\d{4})", expand=False)
        .astype(float)
        .astype("Int64")
    )

    df = df.dropna(subset=["year"])
    return df

def make_safe_column_names(columns):
    safe = []
    for c in columns:
        c2 = c.strip()
        c2 = c2.replace("%", "pct")
        c2 = re.sub(r"\s+", "_", c2)
        c2 = re.sub(r"[\(\)\[\]\{\}]", "", c2)
        c2 = re.sub(r"[^0-9A-Za-z_\/\-]", "", c2)
        c2 = c2.replace("/", "__")
        c2 = re.sub(r"__+", "__", c2)
        c2 = re.sub(r"_+", "_", c2)
        safe.append(c2)

    out = []
    seen = {}
    for c in safe:
        if c not in seen:
            seen[c] = 0
            out.append(c)
        else:
            seen[c] += 1
            out.append(f"{c}__dup{seen[c]}")
    return out

# %% [markdown]
# ## Read and compile all files

# %%
dfs = []
meta = []

for path in csv_files:
    df = read_cbs_csv(path)
    df = normalize_key_cols(df)

    indicator_cols = [c for c in df.columns if c not in ["neighbourhood_code", "neighbourhood", "year"]]

    safe_names = make_safe_column_names(indicator_cols)
    df = df.rename(columns=dict(zip(indicator_cols, safe_names)))

    meta.append({
        "file": path.name,
        "n_rows": len(df),
        "n_cols": len(df.columns),
        "min_year": int(df["year"].min()),
        "max_year": int(df["year"].max()),
    })
    dfs.append(df)

meta_df = pd.DataFrame(meta).sort_values("file")
meta_df
# Out:
#                                                 file  n_rows  n_cols  \
# 0  Socioeconomic status by neighbourhood - All (2...   18309      45
# 1  Socioeconomic status by neighbourhood - All (2...   18309      45
# 2  Socioeconomic status by neighbourhood - All (2...   18309      45
# 3  Socioeconomic status by neighbourhood - All (2...   18309      45
# 4  Socioeconomic status by neighbourhood - Assets...  106056       8
# 5  Socioeconomic status by neighbourhood - Employ...  106056       8
# 6  Socioeconomic status by neighbourhood - Financ...  106056       8
# 7  Socioeconomic status by neighbourhood - High l...  106056       7
# 8  Socioeconomic status by neighbourhood - SES-WO...  106056       7
# 9  Socioeconomic status by neighbourhood - Standa...  106056       8
#
#    min_year  max_year
# 0      2020      2020
# 1      2021      2021
# 2      2022      2022
# 3      2023      2023
# 4      2014      2019
# 5      2014      2019
# 6      2014      2019
# ...

# %%
# Build a stable neighbourhood name mapping (code -> most common name)
name_map = pd.concat([d[["neighbourhood_code", "neighbourhood"]] for d in dfs], ignore_index=True)
name_map = name_map.dropna().drop_duplicates(subset=["neighbourhood_code", "neighbourhood"])
top_name = (name_map.groupby("neighbourhood_code")["neighbourhood"]
            .agg(lambda s: s.value_counts().index[0])
            .rename("neighbourhood"))

# Merge all indicators (drop neighbourhood name during merges to avoid duplicate column-name issues)
wide = dfs[0].drop(columns=["neighbourhood"])
for i, df in enumerate(dfs[1:], start=1):
    wide = wide.merge(
        df.drop(columns=["neighbourhood"]),
        on=["neighbourhood_code", "year"],
        how="outer",
        suffixes=("", f"__from_{i}"),
    )

# Coalesce columns that represent the same indicator coming from multiple files
from_cols = [c for c in wide.columns if "__from_" in c]
bases = set(c.split("__from_")[0] for c in from_cols)

for base in bases:
    variants = [c for c in wide.columns if c == base or c.startswith(base + "__from_")]
    if base not in wide.columns:
        wide[base] = np.nan
    for v in variants:
        if v == base:
            continue
        wide[base] = wide[base].fillna(wide[v])
    wide = wide.drop(columns=[v for v in variants if v != base])

# Attach neighbourhood names back
wide = wide.merge(top_name.reset_index(), on="neighbourhood_code", how="left")

# Reorder
key_cols = ["neighbourhood_code", "neighbourhood", "year"]
other_cols = [c for c in wide.columns if c not in key_cols]
wide = wide[key_cols + sorted(other_cols)]

wide.shape
# Out:
# (179292, 48)

# %%
wide[key_cols].isna().sum()
# Out:
# neighbourhood_code    0
# neighbourhood         0
# year                  0
# dtype: int64

# %%
wide.duplicated(subset=["neighbourhood_code","year"]).sum()
# Out:
# np.int64(0)

# %%
# Rename columns manually 

wide_translations = {
    # Employment History (Arbeidsverleden)
    'Arbeidsverleden_Afgelopen_4_jaar_niet_werkzaam_pct': 'WorkHistory_NotEmployed_Last4Y_pct',
    'Arbeidsverleden_Afgelopen_4_jaar_voortdurend_werkzaam_pct': 'WorkHistory_ConstantlyEmployed_Last4Y_pct',
    'Arbeidsverleden_Afgelopen_4_jr_niet_voortdurend_werkzaam_pct': 'WorkHistory_IntermittentlyEmployed_Last4Y_pct',
    'Arbeidsverleden_Gepensioneerd_pct': 'WorkHistory_Retired_pct',
    
    # Financial Wealth (Financiële Welvaart)
    'Financile_Welvaart_1e_tot_en_met_40e_percentielgroep_pct': 'Wealth_Percentile_1_40_pct',
    'Financile_Welvaart_41e_tot_en_met_80e_percentielgroep_pct': 'Wealth_Percentile_41_80_pct',
    'Financile_Welvaart_81e_tot_en_met_100e_percentielgroep_pct': 'Wealth_Percentile_81_100_pct',
    'Financile_Welvaart_Gemiddelde_percentielgroep_Getal': 'Wealth_Avg_Percentile_Score',
    
    # Standardized Income (Gestandaardiseerd inkomen)
    'Gestandaardiseerd_inkomen_1e_tot_en_met_40e_percentielgroep_pct': 'Income_Percentile_1_40_pct',
    'Gestandaardiseerd_inkomen_41e_tot_en_met_80e_percentielgroep_pct': 'Income_Percentile_41_80_pct',
    'Gestandaardiseerd_inkomen_81e_tot_en_met_100e_percentielgroep_pct': 'Income_Percentile_81_100_pct',
    'Gestandaardiseerd_inkomen_Gemiddelde_percentielgroep_Getal': 'Income_Avg_Percentile_Score',
    
    # Education Levels (Opleidingsniveau)
    # Level 1: Low (Primary/VMBO)
    'Opleidingsniveau_1_Basisonderwijs_vmbo_mbo1_Bovengrens_95pct-interval_pct': 'Edu_Low_Upper95_pct',
    'Opleidingsniveau_1_Basisonderwijs_vmbo_mbo1_Ondergrens_95pct-interval_pct': 'Edu_Low_Lower95_pct',
    'Opleidingsniveau_1_Basisonderwijs_vmbo_mbo1_Waarde_pct': 'Edu_Low_pct',
    # Level 2: Middle (HAVO/VWO/MBO)
    'Opleidingsniveau_2_Havo_vwo_mbo2-4_Bovengrens_95pct-interval_pct': 'Edu_Mid_Upper95_pct',
    'Opleidingsniveau_2_Havo_vwo_mbo2-4_Ondergrens_95pct-interval_pct': 'Edu_Mid_Lower95_pct',
    'Opleidingsniveau_2_Havo_vwo_mbo2-4_Waarde_pct': 'Edu_Mid_pct',
    # Level 3: High (HBO/WO)
    'Opleidingsniveau_3_Hbo_wo_Bovengrens_95pct-interval_pct': 'Edu_High_Upper95_pct',
    'Opleidingsniveau_3_Hbo_wo_Ondergrens_95pct-interval_pct': 'Edu_High_Lower95_pct',
    'Opleidingsniveau_3_Hbo_wo_Waarde_pct': 'Edu_High_pct',
    # High Education General
    'Opleidingsniveau_Hoog_Bovengrens_95pct-interval_pct': 'Edu_High_Total_Upper95_pct',
    'Opleidingsniveau_Hoog_Ondergrens_95pct-interval_pct': 'Edu_High_Total_Lower95_pct',
    'Opleidingsniveau_Hoog_Waarde_pct': 'Edu_High_Total_pct',
    
    # Households
    'Particuliere_huishoudens_Aantal': 'PrivateHouseholds_Count',
    
    # SES-WOA Scores (Wealth, Education, Work)
    'SES-WOA_Deelscore_arbeidsverleden_Gemiddelde_score_Getal': 'SES_Score_WorkHistory_Avg',
    'SES-WOA_Deelscore_financile_welvaart_Gemiddelde_score_Getal': 'SES_Score_Wealth_Avg',
    'SES-WOA_Deelscore_opleidingsniveau_Bovengrens_95pct-interval_Getal': 'SES_Score_Education_Upper95',
    'SES-WOA_Deelscore_opleidingsniveau_Gemiddelde_score_Getal': 'SES_Score_Education_Avg',
    'SES-WOA_Deelscore_opleidingsniveau_Ondergrens_95pct-interval_Getal': 'SES_Score_Education_Lower95',
    'SES-WOA_Totaalscore_Bovengrens_95pct-interval_Getal': 'SES_TotalScore_Upper95',
    'SES-WOA_Totaalscore_Gemiddelde_score_Getal': 'SES_TotalScore_Avg',
    'SES-WOA_Totaalscore_Ondergrens_95pct-interval_Getal': 'SES_TotalScore_Lower95',
    
    # Spread/Dispersion (Spreiding)
    'Spreiding_Spreiding_arbeidsverleden_Waarde_Getal': 'Dispersion_WorkHistory',
    'Spreiding_Spreiding_opleidingsniveau_Bovengrens_95pct-interval_Getal': 'Dispersion_Education_Upper95',
    'Spreiding_Spreiding_opleidingsniveau_Ondergrens_95pct-interval_Getal': 'Dispersion_Education_Lower95',
    'Spreiding_Spreiding_opleidingsniveau_Waarde_Getal': 'Dispersion_Education',
    'Spreiding_Spreiding_totaal_Bovengrens_95pct-interval_Getal': 'Dispersion_Total_Upper95',
    'Spreiding_Spreiding_totaal_Ondergrens_95pct-interval_Getal': 'Dispersion_Total_Lower95',
    'Spreiding_Spreiding_totaal_Waarde_Getal': 'Dispersion_Total',
    'Spreiding_Spreiding_welvaart_Waarde_Getal': 'Dispersion_Wealth',
    
    # Net Worth (Vermogen)
    'Vermogen_1e_tot_en_met_40e_percentielgroep_pct': 'NetWorth_Percentile_1_40_pct',
    'Vermogen_41e_tot_en_met_80e_percentielgroep_pct': 'NetWorth_Percentile_41_80_pct',
    'Vermogen_81e_tot_en_met_100e_percentielgroep_pct': 'NetWorth_Percentile_81_100_pct',
    'Vermogen_Gemiddelde_percentielgroep_Getal': 'NetWorth_Avg_Percentile_Score'
}

# Apply to the 'wide' dataframe
wide.rename(columns=wide_translations, inplace=True)

# %%
wide
# Out:
#        neighbourhood_code                 neighbourhood  year  \
# 0              BU00140000              Binnenstad-Noord  2014
# 1              BU00140000              Binnenstad-Noord  2015
# 2              BU00140000              Binnenstad-Noord  2016
# 3              BU00140000              Binnenstad-Noord  2017
# 4              BU00140000              Binnenstad-Noord  2018
# ...                   ...                           ...   ...
# 179287           WK199232                    Zwartewaal  2023
# 179288           WK199233  Recreatiestrook Brielse Maas  2020
# 179289           WK199233  Recreatiestrook Brielse Maas  2021
# 179290           WK199233  Recreatiestrook Brielse Maas  2022
# 179291           WK199233  Recreatiestrook Brielse Maas  2023
#
#         WorkHistory_NotEmployed_Last4Y_pct  \
# 0                                      8.8
# 1                                      8.9
# 2                                      8.8
# ...

# %% [markdown]
# ## Save outputs

# %%
out_csv = Path("C:/Users/EduardCP/Documents/GitHub/MasterThesis/data/processed/socioeconomic_all.csv")  

wide.to_csv(out_csv, index=False)
